# %% [markdown]
# <a href="https://colab.research.google.com/github/MDIL-SNU/SevenNet/blob/tutorial/tutorial/SevenNet_simple_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SevenNet tutorial: simple
# ---
# This notebook is a simple tutorial for using SevenNet with the CLI.\
# [paper](https://pubs.acs.org/doi/10.1021/acs.jctc.4c00190)\
# [code](https://github.com/MDIL-SNU/SevenNet) \
# We recommend using a GPU. If you're using Colab,\
# [Runtime] -> [Change runtime type] -> [T4 GPU] -> [Save]
#
# If the notebook crashes, restart the notebook. If you're using Colab, \
# [Runtime] -> [Disconnect and delete runtime] -> restart!

# %% [markdown]
# ## 0. Installation
# First of all, let's install SevenNet to our computer!

# %%
# Install SevenNet
# !pip install sevenn

# If you want to check the SevenNet code, clone the repo.
# !git clone https://github.com/MDIL-SNU/SevenNet.git 

import os
working_dir = os.getcwd() # save current path
# Out:
# Requirement already satisfied: sevenn in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: ase in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (3.23.0)
# Requirement already satisfied: braceexpand in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (0.1.7)
# Requirement already satisfied: pyyaml in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (6.0.2)
# Requirement already satisfied: e3nn in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (0.5.1)
# Requirement already satisfied: tqdm in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (4.66.5)
# Requirement already satisfied: scikit-learn in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (1.5.2)
# Requirement already satisfied: torch-geometric in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (2.6.1)
# Requirement already satisfied: numpy<2.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sevenn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from ase->sevenn) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from ase->sevenn) (3.9.2)
# Requirement already satisfied: sympy in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from e3nn->sevenn) (1.13.3)
# Requirement already satisfied: torch>=1.8.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from e3nn->sevenn) (2.4.1)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from e3nn->sevenn) (0.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from scikit-learn->sevenn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from scikit-learn->sevenn) (3.5.0)
# Requirement already satisfied: aiohttp in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (3.10.7)
# Requirement already satisfied: fsspec in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (2024.9.0)
# Requirement already satisfied: jinja2 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (3.1.4)
# Requirement already satisfied: psutil>=5.8.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (6.0.0)
# Requirement already satisfied: pyparsing in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (3.1.4)
# Requirement already satisfied: requests in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch-geometric->sevenn) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (24.1)
# Requirement already satisfied: pillow>=8 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from matplotlib>=3.3.4->ase->sevenn) (6.4.5)
# Requirement already satisfied: opt-einsum in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from opt-einsum-fx>=0.1.4->e3nn->sevenn) (3.4.0)
# Requirement already satisfied: filelock in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (4.12.2)
# Requirement already satisfied: networkx in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from torch>=1.8.0->e3nn->sevenn) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->e3nn->sevenn) (12.6.68)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from aiohttp->torch-geometric->sevenn) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from jinja2->torch-geometric->sevenn) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from requests->torch-geometric->sevenn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from requests->torch-geometric->sevenn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from requests->torch-geometric->sevenn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from requests->torch-geometric->sevenn) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from sympy->e3nn->sevenn) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.4->ase->sevenn) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->sevenn) (1.16.0)

# %%
# check if sevenn is installed well
# !sevenn -h
# Out:
# usage: sevenn [-h] [-m {train_v1,train_v2}] [-w [WORKING_DIR]] [-l LOG] [-s]
#               [-d] [--distributed_backend {nccl,mpi}]
#               input_yaml
#
# sevenn version=0.10.0, train model based on the input.yaml
#
# positional arguments:
#   input_yaml            input.yaml for training
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -m {train_v1,train_v2}, --mode {train_v1,train_v2}
#                         main training script to run. Default is train.
#   -w [WORKING_DIR], --working_dir [WORKING_DIR]
#                         path to write output. Default is cwd.
#   -l LOG, --log LOG     name of logfile, default is log.sevenn
#   -s, --screen          print log to stdout
#   -d, --distributed     set this flag if it is distributed training
#   --distributed_backend {nccl,mpi}
#                         backend for distributed training. Supported: nccl, mpi

# %% [markdown]
# ## 1. Dataset

# %%
# download the dataset
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1TZPJzJaaBPZIiD5gaHC7E0oDngN14rJg
# Out:
# Cloning into 'BOTNet-datasets'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 57 (delta 13), reused 37 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 28.73 MiB | 30.05 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# iso_atoms.xyz  test_1200K.xyz  test_600K.xyz  train_300K.xyz
# README.md      test_300K.xyz   test_dih.xyz   train_mixedT.xyz

# %%
# !unzip seven_tuto_data.zip

# %%
# write structure_list file
# You can increase the data. For example, 150:1000:1

with open('structure_list', 'w') as f:
    f.write('[MD_1200K]\n')
    f.write(f'{working_dir}/train/1200K/OUTCAR 150:1000:10')
    f.write('\n')
    f.write('[MD_600K]\n')
    f.write(f'{working_dir}/train/600K/OUTCAR 150:1000:10')

# %% [markdown]
# ## 2. Training with the CLI

# %%
# %%writefile input.yaml
# model:
#   chemical_species: auto
#   cutoff: 5.0
#
# train:
#   device: cuda   # if you don't have gpu, write 'cpu'
#   is_train_stress: False
#   epoch: 100
#   optim_param:
#     lr: 0.005
#   scheduler_param:
#     gamma: 0.99
#
# data:
#   batch_size: 10
#   load_dataset_path: './structure_list' # write a path of training data
# Out:
# Overwriting input.yaml

# %% [markdown]
# Let's start first training! It takes about 2 minutes to initialize and 6 minutes to train 100 epochs.
# You can reduce epoch to train quickly.

# %%
# !sevenn input.yaml -s
# Out:
# SevenNet: Scalable EquVariance-Enabled Neural Network
# version 0.10.0, Wed Nov  6 00:20:13 2024
# this file: /home/hexagonrose/SevenNet/tutorial/log.sevenn
# reading yaml config...
#                 ****
#               ********                                   .
#               *//////,  ..                               .            ,*.
#                ,,***.         ..                        ,          ********.                                  ./,
#              .      .                ..   /////.       .,       . */////////                               /////////.
#         .&@&/        .                  .(((((((..     /           *//////*.  ...                         *((((((((((.
#      @@@@@@@@@@*    @@@@@@@@@@  @@@@@    *((@@@@@     (     %@@@@@@@@@@  .@@@@@@     ..@@@@.   @@@@@@*    .(@@@@@(((*
#     @@@@@.          @@@@         @@@@@ .   @@@@@      #     %@@@@         @@@@@@@@     @@@@(,  @@@@@@@@.    @@@@@(*.
#     %@@@@@@@&       @@@@@@@@@@    @@@@@   @@@@@      #  ., .%@@@@@@@@@    @@@@@@@@@@   @@@@,   @@@@@@@@@@   @@@@@
#     ,(%@@@@@@@@@    @@@@@@@@@@     @@@@@ @@@@&       (//////%@@@@@@@@@    @@@@  @@@@@@ @@@@  . @@@@@  @@@@@.@@@@@
#         .   @@@@@   @@@@ .       .  @@@@@@@@%   . . ( .////,%@@@@         @@@@    @@@@@@@@@    @@@@@    @@@@@@@@@
#     (@@@@@@@@@@@    @@@@@@@@@@**.    @@@@@@*       *.      .%@@@@@@@@@@   @@@@    . @@@@@@@    @@@@@     .@@@@@@@
#      @@@@@@@@@.     @@@@@@@@@@///,    @@@@.      . /        %@@@@@@@@@@   @@@@***,    @@@@@    @@@@@        @@@@@
#            .           //////////*.               /           .            .*******...             . ,.
#           .&&&&&...     ,//////*.       ...////.  /            ,*/.     .   ,////,               .,/////
#           &@@@@@@                         ,(/((, *           ,((((((.                              .***.
#            ,/@(,                            ..   *            ,((((*
#                                                 ,
#                                                .
# successfully read yaml config!
#
# from model configuration
# chemical_species    : auto
# _number_of_species  : auto
# _type_map           : auto
# irreps_manual       : False
# channel             : 32
# lmax                : 1
# lmax_edge           : -1
# lmax_node           : -1
# is_parity           : True
# radial_basis        : {'radial_basis_name': 'bessel'}
# cutoff_function     : {'cutoff_function_name': 'poly_cut'}
# act_radial          : silu
# cutoff              : 5.0
# weight_nn_hidden_neurons: [64, 64]
# num_convolution_layer: 3
# act_scalar          : {'e': 'silu', 'o': 'tanh'}
# act_gate            : {'e': 'silu', 'o': 'tanh'}
# conv_denominator    : avg_num_neigh
# train_denominator   : False
# train_shift_scale   : False
# use_bias_in_linear  : False
# readout_as_fcn      : False
# readout_fcn_hidden_neurons: [30, 30]
# readout_fcn_activation: relu
# self_connection_type: nequip
# interaction_type    : nequip
# _normalize_sph      : True
#
# from train configuration
# device              : cuda
# random_seed         : 1
# epoch               : 100
# loss                : mse
# loss_param          : {}
# optimizer           : adam
# optim_param         : {'lr': 0.005}
# scheduler           : exponentiallr
# scheduler_param     : {'gamma': 0.99}
# force_loss_weight   : 0.1
# stress_loss_weight  : 1e-06
# per_epoch           : 5
# use_testset         : False
# continue            : {'checkpoint': False, 'reset_optimizer': False, 'reset_scheduler': False, 'reset_epoch': False, \
#                        'use_statistic_values_of_checkpoint': True}
# csv_log             : log.csv
# _num_workers        : 0
# is_train_stress     : False
# train_shuffle       : True
# error_record        : [['Energy', 'RMSE'], ['Force', 'RMSE'], ['Stress', 'RMSE'], ['TotalLoss', 'None']]
# best_metric         : TotalLoss
# is_ddp              : False
# ddp_backend         : nccl
# local_rank          : 0
# rank                : 0
# world_size          : 1
#
# from data configuration
# load_dataset_path   : ['./structure_list']
# dtype               : single
# data_format         : ase
# data_format_args    : {}
# save_dataset_path   : False
# save_by_label       : False
# save_by_train_valid : False
# data_divide_ratio   : 0.1
# batch_size          : 10
# preprocess_num_cores: 1
# shift               : per_atom_energy_mean
# scale               : force_rms
# ***************************************************
# For train_v2, please use load_trainset_path instead
# I will assign load_trainset as load_dataset
# ***************************************************
# Processing...
# graph_build (1): 100%|██████████████████████████| 85/85 [00:06<00:00, 13.77it/s]
# graph_build (1): 100%|██████████████████████████| 85/85 [00:05<00:00, 14.60it/s]
# Done!
# /home/hexagonrose/miniconda3/envs/seven/lib/python3.9/site-packages/torch_geometric/io/fs.py:229: UserWarning: Weights only load failed. Please file an issue to make `torch.load(weights_only=True)` compatible in your case. Please use `torch.serialization.add_safe_globals([AtomGraphData])` to allowlist this global.
#   warnings.warn(f"{warn_msg} Please use "
# run_stat: 100%|█████████████████████████████| 170/170 [00:00<00:00, 1809.16it/s]
# trainset is saved: /home/hexagonrose/SevenNet/tutorial/sevenn_data/trainset.pt
# run_stat: 100%|█████████████████████████████| 170/170 [00:00<00:00, 3545.80it/s]
# ------------------------------------------------------------------------------------------------------------------------
# trainset distribution:
# total_energy        : {'mean': '-1679.641', 'std': '18.032', 'median': '-1680.201', 'max': '-1649.495', 'min': '-1699.840'}
# per_atom_energy     : {'mean': '-4.038', 'std': '0.043', 'median': '-4.039', 'max': '-3.965', 'min': '-4.086'}
# force_of_atoms      : {'mean': '-0.000', 'std': '0.656', 'median': '-0.000', 'max': '6.126', 'min': '-5.642'}
# stress              : {'mean': '0.004', 'std': '0.005', 'median': '0.003', 'max': '0.017', 'min': '-0.004'}
# num_neighbor        : {'mean': '27.180', 'std': '2.249', 'median': '27.000', 'max': '37.000', 'min': '19.000'}
# # atoms (node)      : {'Cl': 5440, 'S': 27200, 'Li': 32640, 'P': 5440, 'total': 70720}
# # structures (graph): 170
# ------------------------------------------------------------------------------------------------------------------------
# Known species are obtained from the dataset
# shift is obtained from statistics
# scale is obtained from statistics
# conv_denominator is obtained from statistics
#
# Model building...
# Irreps of features
# edge_feature        : 1x0e+1x1o
# 0th node            : 32x0e
# 1th node            : 32x0e+32x1o
# 2th node            : 32x0e+32x1o+32x1e
# readout irreps      : 32x0e
# # learnable parameters: 82072
#
# Failed to get error recorder key: TotalLoss or validset is missing. There will be no best checkpoint.
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 1/100  lr: 0.005000
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.044925            1.132885    0.044799
# Epoch 1 elapsed: 0:00:07.50
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 2/100  lr: 0.004950
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.044495            1.116025    0.043497
# Epoch 2 elapsed: 0:00:03.96
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 3/100  lr: 0.004901
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.039672            1.015928    0.035978
# Epoch 3 elapsed: 0:00:03.97
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 4/100  lr: 0.004851
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.026267            0.787456    0.021359
# Epoch 4 elapsed: 0:00:03.91
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 5/100  lr: 0.004803
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.023467            0.640850    0.014240
# Epoch 5 elapsed: 0:00:03.72
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 6/100  lr: 0.004755
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.015115            0.560094    0.010685
# Epoch 6 elapsed: 0:00:03.52
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 7/100  lr: 0.004707
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.014967            0.512782    0.008989
# Epoch 7 elapsed: 0:00:03.86
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 8/100  lr: 0.004660
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.013125            0.479515    0.007837
# Epoch 8 elapsed: 0:00:03.73
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 9/100  lr: 0.004614
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.011390            0.447361    0.006801
# Epoch 9 elapsed: 0:00:03.78
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 10/100  lr: 0.004568
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.015442            0.418325    0.006072
# Epoch 10 elapsed: 0:00:03.89
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 11/100  lr: 0.004522
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.013096            0.389096    0.005218
# Epoch 11 elapsed: 0:00:03.75
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 12/100  lr: 0.004477
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.010204            0.366639    0.004585
# Epoch 12 elapsed: 0:00:03.71
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 13/100  lr: 0.004432
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.013260            0.350753    0.004277
# Epoch 13 elapsed: 0:00:03.49
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 14/100  lr: 0.004388
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.011747            0.337499    0.003935
# Epoch 14 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 15/100  lr: 0.004344
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.009197            0.323222    0.003567
# Epoch 15 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 16/100  lr: 0.004300
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006654            0.311340    0.003275
# Epoch 16 elapsed: 0:00:03.20
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 17/100  lr: 0.004257
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.009023            0.299801    0.003077
# Epoch 17 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 18/100  lr: 0.004215
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006355            0.288994    0.002824
# Epoch 18 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 19/100  lr: 0.004173
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006749            0.278087    0.002623
# Epoch 19 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 20/100  lr: 0.004131
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004925            0.268560    0.002428
# Epoch 20 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 21/100  lr: 0.004090
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005833            0.261079    0.002306
# Epoch 21 elapsed: 0:00:03.21
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 22/100  lr: 0.004049
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.008279            0.254484    0.002227
# Epoch 22 elapsed: 0:00:03.29
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 23/100  lr: 0.004008
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.009119            0.248120    0.002135
# Epoch 23 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 24/100  lr: 0.003968
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006589            0.243185    0.002015
# Epoch 24 elapsed: 0:00:03.31
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 25/100  lr: 0.003928
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.007894            0.238855    0.001964
# Epoch 25 elapsed: 0:00:03.75
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 26/100  lr: 0.003889
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005411            0.234979    0.001870
# Epoch 26 elapsed: 0:00:03.50
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 27/100  lr: 0.003850
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004463            0.230583    0.001792
# Epoch 27 elapsed: 0:00:03.44
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 28/100  lr: 0.003812
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004782            0.227319    0.001745
# Epoch 28 elapsed: 0:00:03.43
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 29/100  lr: 0.003774
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005432            0.223787    0.001699
# Epoch 29 elapsed: 0:00:03.59
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 30/100  lr: 0.003736
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004849            0.220358    0.001642
# Epoch 30 elapsed: 0:00:03.47
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 31/100  lr: 0.003699
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.007913            0.217796    0.001644
# Epoch 31 elapsed: 0:00:03.40
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 32/100  lr: 0.003662
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006494            0.215306    0.001587
# Epoch 32 elapsed: 0:00:03.39
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 33/100  lr: 0.003625
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.007233            0.212780    0.001561
# Epoch 33 elapsed: 0:00:03.35
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 34/100  lr: 0.003589
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006124            0.210811    0.001519
# Epoch 34 elapsed: 0:00:03.36
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 35/100  lr: 0.003553
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006777            0.208206    0.001491
# Epoch 35 elapsed: 0:00:03.55
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 36/100  lr: 0.003517
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005228            0.206170    0.001444
# Epoch 36 elapsed: 0:00:03.22
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 37/100  lr: 0.003482
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004093            0.204345    0.001409
# Epoch 37 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 38/100  lr: 0.003447
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005581            0.202542    0.001399
# Epoch 38 elapsed: 0:00:03.29
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 39/100  lr: 0.003413
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004252            0.200626    0.001360
# Epoch 39 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 40/100  lr: 0.003379
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003849            0.199059    0.001336
# Epoch 40 elapsed: 0:00:03.40
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 41/100  lr: 0.003345
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003163            0.197361    0.001308
# Epoch 41 elapsed: 0:00:03.22
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 42/100  lr: 0.003311
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004506            0.195720    0.001297
# Epoch 42 elapsed: 0:00:03.30
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 43/100  lr: 0.003278
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005660            0.194300    0.001290
# Epoch 43 elapsed: 0:00:03.29
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 44/100  lr: 0.003246
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003504            0.192914    0.001253
# Epoch 44 elapsed: 0:00:03.42
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 45/100  lr: 0.003213
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003188            0.191534    0.001233
# Epoch 45 elapsed: 0:00:03.52
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 46/100  lr: 0.003181
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005972            0.190528    0.001246
# Epoch 46 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 47/100  lr: 0.003149
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004503            0.189233    0.001214
# Epoch 47 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 48/100  lr: 0.003118
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.008261            0.188269    0.001250
# Epoch 48 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 49/100  lr: 0.003086
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.006678            0.187022    0.001211
# Epoch 49 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 50/100  lr: 0.003056
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003569            0.185996    0.001166
# Epoch 50 elapsed: 0:00:03.50
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 51/100  lr: 0.003025
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004769            0.184713    0.001160
# Epoch 51 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 52/100  lr: 0.002995
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003956            0.183681    0.001140
# Epoch 52 elapsed: 0:00:03.32
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 53/100  lr: 0.002965
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003592            0.183133    0.001131
# Epoch 53 elapsed: 0:00:03.32
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 54/100  lr: 0.002935
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004323            0.182187    0.001125
# Epoch 54 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 55/100  lr: 0.002906
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004107            0.181193    0.001111
# Epoch 55 elapsed: 0:00:03.45
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 56/100  lr: 0.002877
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005935            0.180382    0.001120
# Epoch 56 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 57/100  lr: 0.002848
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005584            0.179279    0.001103
# Epoch 57 elapsed: 0:00:03.36
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 58/100  lr: 0.002820
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004145            0.178643    0.001081
# Epoch 58 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 59/100  lr: 0.002791
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003718            0.177783    0.001067
# Epoch 59 elapsed: 0:00:03.32
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 60/100  lr: 0.002763
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003477            0.176936    0.001056
# Epoch 60 elapsed: 0:00:03.44
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 61/100  lr: 0.002736
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002923            0.176442    0.001046
# Epoch 61 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 62/100  lr: 0.002708
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004538            0.175614    0.001049
# Epoch 62 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 63/100  lr: 0.002681
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003821            0.174810    0.001033
# Epoch 63 elapsed: 0:00:03.35
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 64/100  lr: 0.002655
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004008            0.174158    0.001027
# Epoch 64 elapsed: 0:00:03.32
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 65/100  lr: 0.002628
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003276            0.173339    0.001012
# Epoch 65 elapsed: 0:00:03.37
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 66/100  lr: 0.002602
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004386            0.172925    0.001016
# Epoch 66 elapsed: 0:00:03.26
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 67/100  lr: 0.002576
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004002            0.172429    0.001007
# Epoch 67 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 68/100  lr: 0.002550
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003036            0.171673    0.000992
# Epoch 68 elapsed: 0:00:03.35
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 69/100  lr: 0.002524
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003735            0.171119    0.000990
# Epoch 69 elapsed: 0:00:03.32
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 70/100  lr: 0.002499
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004560            0.170624    0.000991
# Epoch 70 elapsed: 0:00:03.39
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 71/100  lr: 0.002474
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003428            0.169623    0.000971
# Epoch 71 elapsed: 0:00:03.22
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 72/100  lr: 0.002449
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004946            0.169155    0.000978
# Epoch 72 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 73/100  lr: 0.002425
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005049            0.169052    0.000978
# Epoch 73 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 74/100  lr: 0.002401
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002979            0.168115    0.000951
# Epoch 74 elapsed: 0:00:03.27
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 75/100  lr: 0.002377
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004275            0.167735    0.000956
# Epoch 75 elapsed: 0:00:03.41
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 76/100  lr: 0.002353
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002489            0.166961    0.000935
# Epoch 76 elapsed: 0:00:03.37
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 77/100  lr: 0.002329
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003425            0.166349    0.000934
# Epoch 77 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 78/100  lr: 0.002306
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.005086            0.165863    0.000943
# Epoch 78 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 79/100  lr: 0.002283
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004125            0.165289    0.000928
# Epoch 79 elapsed: 0:00:03.36
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 80/100  lr: 0.002260
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002799            0.164781    0.000913
# Epoch 80 elapsed: 0:00:03.48
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 81/100  lr: 0.002238
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004536            0.164355    0.000921
# Epoch 81 elapsed: 0:00:03.28
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 82/100  lr: 0.002215
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002671            0.164137    0.000905
# Epoch 82 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 83/100  lr: 0.002193
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002957            0.163561    0.000900
# Epoch 83 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 84/100  lr: 0.002171
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002798            0.163288    0.000897
# Epoch 84 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 85/100  lr: 0.002149
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003796            0.162710    0.000897
# Epoch 85 elapsed: 0:00:03.42
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 86/100  lr: 0.002128
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002854            0.162044    0.000883
# Epoch 86 elapsed: 0:00:03.25
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 87/100  lr: 0.002107
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002649            0.161718    0.000879
# Epoch 87 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 88/100  lr: 0.002086
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002625            0.161402    0.000875
# Epoch 88 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 89/100  lr: 0.002065
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003329            0.160613    0.000871
# Epoch 89 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 90/100  lr: 0.002044
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002464            0.160334    0.000863
# Epoch 90 elapsed: 0:00:03.43
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 91/100  lr: 0.002024
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002623            0.160019    0.000860
# Epoch 91 elapsed: 0:00:03.24
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 92/100  lr: 0.002003
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002630            0.159543    0.000855
# Epoch 92 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 93/100  lr: 0.001983
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004018            0.159063    0.000860
# Epoch 93 elapsed: 0:00:03.31
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 94/100  lr: 0.001964
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004093            0.158746    0.000857
# Epoch 94 elapsed: 0:00:03.34
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 95/100  lr: 0.001944
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003039            0.158290    0.000844
# Epoch 95 elapsed: 0:00:03.46
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 96/100  lr: 0.001924
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002379            0.157874    0.000836
# Epoch 96 elapsed: 0:00:03.35
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 97/100  lr: 0.001905
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.001983            0.157464    0.000830
# Epoch 97 elapsed: 0:00:03.38
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 98/100  lr: 0.001886
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.003047            0.157098    0.000832
# Epoch 98 elapsed: 0:00:03.33
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 99/100  lr: 0.001867
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.004911            0.156763    0.000843
# Epoch 99 elapsed: 0:00:03.31
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 100/100  lr: 0.001849
# ------------------------------------------------------------------------------------------------------------------------
#           Energy_RMSE (eV/atom)   Force_RMSE (eV/Å)   TotalLoss
# -----------------------------------------------------------------
# trainset               0.002512            0.156328    0.000821
# Epoch 100 elapsed: 0:00:03.39
# Total wall time: 0:06:02.71

# %% [markdown]
# Best model is saved as 'checkpoint_best.pth'. You can also check the training log at log.sevenn

# %%
# !ls
# Out:
# SevenNet_python_tutorial.ipynb	checkpoint_45.pth  checkpoint_95.pth
# SevenNet_simple_tutorial.ipynb	checkpoint_5.pth   evaluation
# checkpoint			checkpoint_50.pth  input.yaml
# checkpoint_10.pth		checkpoint_55.pth  lc.csv
# checkpoint_100.pth		checkpoint_60.pth  log.sevenn
# checkpoint_15.pth		checkpoint_65.pth  seven_tuto_data.zip
# checkpoint_20.pth		checkpoint_70.pth  sevenn_data
# checkpoint_25.pth		checkpoint_75.pth  structure_list
# checkpoint_30.pth		checkpoint_80.pth  train
# checkpoint_35.pth		checkpoint_85.pth
# checkpoint_40.pth		checkpoint_90.pth

# %% [markdown]
# ## 3. Model test
# LPSC relax?
